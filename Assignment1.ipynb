# %% [markdown]
# <a href="https://colab.research.google.com/github/HadeelHaj366/LLM-Assisted-Light/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np

# %%
#img = cv2.imread('lena.jpg', 1)

# %%
img = np.ones([512,512,3], np.uint8)*255

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
#img= cv2.line(img, (0,0), (255,255), (0,255,0), 10)

# %%
#cv2_imshow(img)

# %%
#img = cv2.arrowedLine(img, (255,0), (255,255), (255,0,0), 10)
#cv2_imshow(img)

# %%
#img = cv2.rectangle(img, (384,0), (510,128), (0,0,255), 10)
#cv2_imshow(img)

# %%
img = cv2.circle(img, (200,350), 100, (0,0,0), 10)
img = cv2.circle(img, (300,350), 100, (0,0,0), 10)
img = cv2.line(img, (190,350), (310,350), (255,255,255), 10)
img = cv2.line(img, (190,360), (310,360), (255,255,255), 10)
img = cv2.line(img, (190,340), (310,340), (255,255,255), 10)
img = cv2.line(img, (190,330), (310,330), (255,255,255), 10)
img = cv2.line(img, (200,360), (300,360), (0,0,0), 10)
mg = cv2.line(img, (250,350), (250,370), (255,255,255), 10)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
font = cv2.FONT_HERSHEY_TRIPLEX
img = cv2.putText(img, 'GUCCI', (60,150), font, 4, (0,0,0), 10, cv2.LINE_AA)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
